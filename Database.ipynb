# %%
import os
import mysql.connector
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline

# %% [markdown]
# # KONEKSI DATABASE 1

# %%
connect = mysql.connector.connect(host='localhost', user='root', passwd='', db='classicmodels')

# %%
model_tabel_classic = pd.read_sql_query('SHOW TABLES FROM classicmodels',connect)

# %%
model_tabel_classic
# Out:
#   Tables_in_classicmodels
# 0               customers
# 1               employees
# 2                 offices
# 3            orderdetails
# 4                  orders
# 5                payments
# 6            productlines
# 7                products

# %%
data_customer = ("SELECT * FROM customers")

# %%
df = pd.read_sql_query(data_customer, connect)

# %%
df
# Out:
#      customerNumber                    customerName contactLastName  \
# 0               103               Atelier graphique         Schmitt
# 1               112              Signal Gift Stores            King
# 2               114      Australian Collectors, Co.        Ferguson
# 3               119               La Rochelle Gifts         Labrune
# 4               121              Baane Mini Imports      Bergulfsen
# ..              ...                             ...             ...
# 117             486    Motor Mint Distributors Inc.         Salazar
# 118             487        Signal Collectibles Ltd.          Taylor
# 119             489  Double Decker Gift Stores, Ltd           Smith
# 120             495            Diecast Collectables          Franco
# 121             496               Kelly's Gift Shop         Snowden
#
#     contactFirstName           phone                  addressLine1  \
# 0            Carine       40.32.2555                54, rue Royale
# ...

# %%
df.to_excel('data Custommer.xlsx', index=False)

# %%
df = pd.read_excel("data Custommer.xlsx")

# %%
df
# Out:
#      customerNumber                    customerName contactLastName  \
# 0               103               Atelier graphique         Schmitt
# 1               112              Signal Gift Stores            King
# 2               114      Australian Collectors, Co.        Ferguson
# 3               119               La Rochelle Gifts         Labrune
# 4               121              Baane Mini Imports      Bergulfsen
# ..              ...                             ...             ...
# 117             486    Motor Mint Distributors Inc.         Salazar
# 118             487        Signal Collectibles Ltd.          Taylor
# 119             489  Double Decker Gift Stores, Ltd           Smith
# 120             495            Diecast Collectables          Franco
# 121             496               Kelly's Gift Shop         Snowden
#
#     contactFirstName           phone                  addressLine1  \
# 0            Carine       40.32.2555                54, rue Royale
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df[['phone']]
# Out:
#               phone
# 0        40.32.2555
# 1        7025551838
# 2      03 9520 4555
# 3        40.67.8555
# 4        07-98 9555
# ..              ...
# 117      2155559857
# 118      4155554312
# 119  (171) 555-7555
# 120      6175552555
# 121   +64 9 5555500
#
# [122 rows x 1 columns]

# %%
df['customerNumber'].mean()
# Out:
# 296.4016393442623

# %%
data_payments = ("SELECT * FROM payments")

# %%
dp = pd.read_sql_query(data_payments, connect)

# %%
dp
# Out:
#      customerNumber checkNumber paymentDate    amount
# 0               103    HQ336336  2004-10-19   6066.78
# 1               103    JM555205  2003-06-05  14571.44
# 2               103    OM314933  2004-12-18   1676.14
# 3               112    BO864823  2004-12-17  14191.12
# 4               112     HQ55022  2003-06-06  32641.98
# ..              ...         ...         ...       ...
# 268             495    BH167026  2003-12-26  59265.14
# 269             495    FN155234  2004-05-14   6276.60
# 270             496    EU531600  2005-05-25  30253.75
# 271             496    MB342426  2003-07-16  32077.44
# 272             496     MN89921  2004-12-31  52166.00
#
# [273 rows x 4 columns]

# %%
dp.head(10)
# Out:
#    customerNumber checkNumber paymentDate    amount
# 0             103    HQ336336  2004-10-19   6066.78
# 1             103    JM555205  2003-06-05  14571.44
# 2             103    OM314933  2004-12-18   1676.14
# 3             112    BO864823  2004-12-17  14191.12
# 4             112     HQ55022  2003-06-06  32641.98
# 5             112    ND748579  2004-08-20  33347.88
# 6             114     GG31455  2003-05-20  45864.03
# 7             114    MA765515  2004-12-15  82261.22
# 8             114    NP603840  2003-05-31   7565.08
# 9             114     NR27552  2004-03-10  44894.74

# %%
dp.tail(10)
# Out:
#      customerNumber checkNumber paymentDate    amount
# 263             486    JB117768  2003-03-20  25833.14
# 264             487    AH612904  2003-09-28  29997.09
# 265             487    PT550181  2004-02-29  12573.28
# 266             489    OC773849  2003-12-04  22275.73
# 267             489    PO860906  2004-01-31   7310.42
# 268             495    BH167026  2003-12-26  59265.14
# 269             495    FN155234  2004-05-14   6276.60
# 270             496    EU531600  2005-05-25  30253.75
# 271             496    MB342426  2003-07-16  32077.44
# 272             496     MN89921  2004-12-31  52166.00

# %%
dp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273 entries, 0 to 272
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customerNumber  273 non-null    int64
#  1   checkNumber     273 non-null    object
#  2   paymentDate     273 non-null    object
#  3   amount          273 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 8.7+ KB

# %%
dp['customerNumber'].median()
# Out:
# 250.0

# %%
data_order = ("SELECT * FROM orders")

# %%
do = pd.read_sql_query(data_order, connect)

# %%
do.head(10)
# Out:
#    orderNumber   orderDate requiredDate shippedDate   status  \
# 0        10100  2003-01-06   2003-01-13  2003-01-10  Shipped
# 1        10101  2003-01-09   2003-01-18  2003-01-11  Shipped
# 2        10102  2003-01-10   2003-01-18  2003-01-14  Shipped
# 3        10103  2003-01-29   2003-02-07  2003-02-02  Shipped
# 4        10104  2003-01-31   2003-02-09  2003-02-01  Shipped
# 5        10105  2003-02-11   2003-02-21  2003-02-12  Shipped
# 6        10106  2003-02-17   2003-02-24  2003-02-21  Shipped
# 7        10107  2003-02-24   2003-03-03  2003-02-26  Shipped
# 8        10108  2003-03-03   2003-03-12  2003-03-08  Shipped
# 9        10109  2003-03-10   2003-03-19  2003-03-11  Shipped
#
#                                             comments  customerNumber
# 0                                               None             363
# 1                             Check on availability.             128
# 2                                               None             181
# ...

# %%
do.tail(10)
# Out:
#      orderNumber   orderDate requiredDate shippedDate      status  \
# 316        10416  2005-05-10   2005-05-16  2005-05-14     Shipped
# 317        10417  2005-05-13   2005-05-19  2005-05-19    Disputed
# 318        10418  2005-05-16   2005-05-24  2005-05-20     Shipped
# 319        10419  2005-05-17   2005-05-28  2005-05-19     Shipped
# 320        10420  2005-05-29   2005-06-07        None  In Process
# 321        10421  2005-05-29   2005-06-06        None  In Process
# 322        10422  2005-05-30   2005-06-11        None  In Process
# 323        10423  2005-05-30   2005-06-05        None  In Process
# 324        10424  2005-05-31   2005-06-08        None  In Process
# 325        10425  2005-05-31   2005-06-07        None  In Process
#
#                                               comments  customerNumber
# 316                                               None             386
# 317  Customer doesn't like the colors and precision...             141
# ...

# %% [markdown]
# # KONEKSI DATABASE 2

# %%
connect2 = mysql.connector.connect(host='localhost', user='root', passwd='', db='phi_minimart')

# %%
model_tabel_minimart = pd.read_sql_query("SHOW TABLES FROM phi_minimart ", connect)

# %%
model_tabel_minimart
# Out:
#   Tables_in_phi_minimart
# 0              ms_cabang
# 1        ms_harga_harian
# 2            ms_karyawan
# 3            ms_kategori
# 4                ms_kota
# 5              ms_produk
# 6            ms_propinsi
# 7           tr_penjualan

# %%
data_karyawan = ("SELECT * FROM ms_karyawan")

# %%
data_karyawan
# Out:
# 'SELECT * FROM ms_karyawan'

# %%
dk = pd.read_sql_query(data_karyawan, connect2)

# %%
dk
# Out:
#    kode_cabang kode_karyawan nama_depan nama_belakang jenis_kelamin
# 0   CABANG-039       039-147    Bintang         Maven             W
# 1   CABANG-047       047-181       Eria      Setiawan             W
# 2   CABANG-065       065-282     Galang      Setiawan             P
# 3   CABANG-039       039-031   Kristina         Damai             W
# 4   CABANG-047       047-075        Eko         Rukun             P
# 5   CABANG-065       065-076     Natali       Menawan             W
# 6   CABANG-039       039-214      Mawar         Mardi             W
# 7   CABANG-047       047-055      Erman         Margo             P
# 8   CABANG-065       065-061        Ayu       Pekerti             W
# 9   CABANG-039       039-044      Ferdy      Tenteram             P
# 10  CABANG-047       047-133      Harum         Maven             W
# 11  CABANG-065       065-023      Harum      Selangit             W
# 12  CABANG-039       039-212       Agus      Dewangga             P
# ...

# %%
dk[['kode_karyawan','kode_cabang']]
# Out:
#    kode_karyawan kode_cabang
# 0        039-147  CABANG-039
# 1        047-181  CABANG-047
# 2        065-282  CABANG-065
# 3        039-031  CABANG-039
# 4        047-075  CABANG-047
# 5        065-076  CABANG-065
# 6        039-214  CABANG-039
# 7        047-055  CABANG-047
# 8        065-061  CABANG-065
# 9        039-044  CABANG-039
# 10       047-133  CABANG-047
# 11       065-023  CABANG-065
# 12       039-212  CABANG-039
# 13       047-031  CABANG-047
# 14       065-060  CABANG-065
# 15       039-053  CABANG-039
# 16       047-244  CABANG-047
# 17       065-007  CABANG-065
# 18       039-127  CABANG-039
# 19       047-286  CABANG-047
# 20       065-258  CABANG-065
# 21       039-203  CABANG-039
# 22       047-006  CABANG-047
# 23       065-094  CABANG-065
# 24       039-156  CABANG-039
# 25       047-105  CABANG-047
# 26       065-206  CABANG-065
# 27       039-084  CABANG-039
# 28       047-128  CABANG-047
# 29       065-078  CABANG-065

# %%
dk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   kode_cabang    30 non-null     object
#  1   kode_karyawan  30 non-null     object
#  2   nama_depan     30 non-null     object
#  3   nama_belakang  30 non-null     object
#  4   jenis_kelamin  30 non-null     object
# dtypes: object(5)
# memory usage: 1.3+ KB

# %%
dk.describe()
# Out:
#        kode_cabang kode_karyawan nama_depan nama_belakang jenis_kelamin
# count           30            30         30            30            30
# unique           3            30         26            19             2
# top     CABANG-065       065-078   Kristina      Setiawan             P
# freq            10             1          2             4            15

# %%
data_penjualan = ("SELECT * FROM tr_penjualan")

# %%
d_penjual = pd.read_sql_query(data_penjualan, connect2)

# %%
d_penjual
# Out:
#        tgl_transaksi kode_cabang kode_kasir kode_item   kode_produk  \
# 0         2008-01-01  CABANG-039    039-053   ITM-038  PROD-0000040
# 1         2008-01-01  CABANG-039    039-127   ITM-020  PROD-0000023
# 2         2008-01-01  CABANG-039    039-156   ITM-017  PROD-0000020
# 3         2008-01-01  CABANG-039    039-212   ITM-002  PROD-0000002
# 4         2008-01-01  CABANG-039    039-044   ITM-034  PROD-0000036
# ...              ...         ...        ...       ...           ...
# 437719    2008-12-30  CABANG-065    065-076   ITM-033  PROD-0000035
# 437720    2008-12-30  CABANG-065    065-094   ITM-012  PROD-0000012
# 437721    2008-12-30  CABANG-065    065-076   ITM-033  PROD-0000035
# 437722    2008-12-30  CABANG-065    065-206   ITM-032  PROD-0000034
# 437723    2008-12-30  CABANG-065    065-258   ITM-019  PROD-0000022
#
#         jumlah_pembelian
# 0                     12
# 1                     16
# 2                     12
# 3                     11
# ...

# %%
d_penjual[['jumlah_pembelian']].median()
# Out:
# jumlah_pembelian    11.0
# dtype: float64

# %%
d_penjual['jumlah_pembelian'].head(20).plot.hist(bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
d_penjual['jumlah_pembelian'].value_counts()
# Out:
# 12    22226
# 9     22197
# 17    22025
# 13    22010
# 15    21966
# 16    21950
# 20    21941
# 18    21885
# 3     21879
# 1     21875
# 10    21868
# 19    21861
# 5     21861
# 7     21856
# 8     21812
# 14    21758
# 2     21758
# 6     21719
# 4     21648
# 11    21629
# Name: jumlah_pembelian, dtype: int64

# %%
dp = d_penjual['jumlah_pembelian'].value_counts().plot.bar()
dp.set_ylabel('data banyaknya penjualan')
# Out:
# Text(0, 0.5, 'data banyaknya penjualan')

# %%
d_penjual.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 437724 entries, 0 to 437723
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   tgl_transaksi     437724 non-null  datetime64[ns]
#  1   kode_cabang       437724 non-null  object
#  2   kode_kasir        437724 non-null  object
#  3   kode_item         437724 non-null  object
#  4   kode_produk       437724 non-null  object
#  5   jumlah_pembelian  437724 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 20.0+ MB

# %%
d_penjual.describe()
# Out:
#        jumlah_pembelian
# count     437724.000000
# mean          10.512965
# std            5.763765
# min            1.000000
# 25%            6.000000
# 50%           11.000000
# 75%           16.000000
# max           20.000000
